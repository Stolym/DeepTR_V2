# %%
from SourcesPaperspace import brain as b
from SourcesPaperspace import dqn as d

import os
# Out:
# 1 Physical GPUs, 1 Logical GPU

# %%
path = os.getcwd()
print(path + "\\replay_formatted")
# Out:
# C:\Users\node\PycharmProjects\GodUKE\replay_formatted

# %%
_brain_ = b.Brain()
_dqn_ = d.DQN(Brain=_brain_, NameModel="Model.ckpt", DirModel="Datav4", DrawSim=False, ModName="lenshu3ng.tbm",
                ReplayData=path, ConvertReplay=False, LoadReplay=False, JoinReplay=False,
                SimulationTrainBegin=-1, SimulationSize=4, MaxMemory=10000,
                PlayerID=2, EnemyID=1, Epsilon=0.03, rEpsilon=0.999, mEpsilon=0.03)

_dqn_.encode["Brain"].advancedTrain(data=_dqn_.fbatch, sequence_size=15, encode=_dqn_.encode, step=10, batch_size=128, epochs=24)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# limbPositionsEnemy (InputLayer  [(None, 15, 63)]     0           []
# )
# __________________________________________________________________________________________________
# limbVelocitiesEnemy (InputLaye  [(None, 15, 63)]     0           []
# r)
# __________________________________________________________________________________________________
# groinRotationsEnemy (InputLaye  [(None, 15, 16)]     0           []
# r)
# __________________________________________________________________________________________________
# jointStatesEnemy (InputLayer)   [(None, 15, 22)]     0           []
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 15, 256)      16384       ['limbPositionsEnemy[0][0]']
# ...
